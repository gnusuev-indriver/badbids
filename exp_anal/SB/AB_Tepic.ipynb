# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pathlib
import warnings
warnings.filterwarnings("ignore")

import pathlib
import pandas as pd
from pathlib import Path
import numpy as np
from datetime import timedelta

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.offline as pyo
import mmh3
from typing import Dict



from src.download_AB import download_experiment_data, download_recprice_data, download_order_data, download_bid_data
from src.metrics_AB import calculate_absolute_metrics, get_switchback_results, calculate_ratio_metrics
from src.prepare import prepare_recprice_data, prepare_order_data, prepare_bid_data, get_orders_with_recprice_df, get_hex
from src.visualization import plot_switches_matrix, plot_conversions_by_time, plot_prices_by_time
from src.visualization import plot_metric_by_time, plot_metric_by_hex

# %% [markdown]
# ## SB Results: Bad Bids
#
# - link

# %% [markdown]
# ### Костыли

# %%
# salt - рандомная строка длиной 8 хранится в experiment.salt
# distribution_map - словарь вида {"GroupA": 50, "Control": 50}, где сумма значений должна быть 100
#  Порядок важен! Control всегда последний
def group_name(split_id: str, salt: str, distribution_map: Dict[str, int]):
    if sum(distribution_map.values()) != 100:
        raise Exception("Incorrect distribution")

    if list(distribution_map.keys())[-1] != "Control":
        raise Exception("Last group should be Control")

    if len(salt) != 8:
        raise Exception("Incorrect salt")

    # Хэш по соль экспа + split_id (id пользователя или девайса)
    murmur_hash: int = mmh3.hash(f"{salt}{split_id}", 1, False)
    reminder = murmur_hash % 100
    s = 0
    for k, v in distribution_map.items():
        s += v
        if reminder < s:
            return k

# %% [markdown]
# ### Parameters

# %% [markdown]
# __Mutable__

# %%
EXP_ID = 2641
USER_NAME = 'nusuev_ab'+str(EXP_ID)

ORDER_TYPE = 'auto_econom'
ORDER_TYPE_ID = 1

DAYS_BEFORE = 0

# %% [markdown]
# __Immutable__

# %%
DATA_ROOT_PATH = pathlib.Path(f'data/exp_id={EXP_ID}')
if not DATA_ROOT_PATH.exists():
    DATA_ROOT_PATH.mkdir(parents=True, exist_ok=True)
    

PLOT_ROOT_PATH = pathlib.Path(f'data/exp_id={EXP_ID}/plots')
if not PLOT_ROOT_PATH.exists():
    PLOT_ROOT_PATH.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Experiment Data

# %% [markdown]
# __Download__

# %%
df_exp = download_experiment_data(exp_id=EXP_ID, user_name=USER_NAME)

# df_exp['hour'] = df_exp['switch_start_dttm'].dt.hour
# df_exp['hour'] = df_exp['hour'].astype('category')
# df_exp['weekday_name'] = df_exp['switch_start_dttm'].dt.day_name()
# df_exp['weekday_name'] = df_exp['weekday_name'].astype('category')

df_exp.to_parquet(DATA_ROOT_PATH / 'df_exp.pqt')

EXP_START_DATE = df_exp.utc_start_dttm.dt.date.astype('str').iloc[0]
EXP_STOP_DATE = df_exp.utc_finish_dttm.dt.date.astype('str').iloc[0]
BEFORE_START_DATE = (df_exp.utc_start_dttm.dt.date - timedelta(days=DAYS_BEFORE)).astype('str').iloc[0]
CITY_ID = df_exp.city_id.iloc[0]
# EXP_NAME = df_exp.exp_name.iloc[0]

EXP_SALT = df_exp['exp_salt'].iloc[0]
DISTRIBUTION_MAP = {"GroupA": 50, "Control": 50}

print(
    f"""
    before_start_date: {BEFORE_START_DATE}
    exp_start_date: {EXP_START_DATE}
    exp_stop_date: {EXP_STOP_DATE}
    city_id: {CITY_ID}
    exp_salt: {EXP_SALT}
    distribution_map: {DISTRIBUTION_MAP}
    """
)
# Out:
#     before_start_date: 2025-02-28
#     exp_start_date: 2025-02-28
#     exp_stop_date: 2025-03-28
#     city_id: 4241
#     exp_salt: QKLy5R6k
#     distribution_map: {'GroupA': 50, 'Control': 50}

# %% [markdown]
# __Validity__

# %% [markdown]
# ### Metrics Data

# %% [markdown]
# __Recprice__

# %%
df_recprice = download_recprice_data(
    start_date=BEFORE_START_DATE,
    stop_date=EXP_STOP_DATE,
    city_id=CITY_ID,
    user_name=USER_NAME,
    # printBool=True
)

# Применяем функцию group_name к каждой строке, используя user_id как split_id
df_recprice['recprice_group_name'] = df_recprice.apply(
    lambda row: 'Before' if row['utc_recprice_dttm'] < pd.Timestamp(EXP_START_DATE, tz='UTC') 
    else group_name(row['user_id'], EXP_SALT, DISTRIBUTION_MAP),
    axis=1
)

df_recprice.to_parquet(DATA_ROOT_PATH / 'df_recprice.pqt')

# %%
df_recprice = pd.read_parquet(DATA_ROOT_PATH / 'df_recprice.pqt')
df_recprice_prepared = prepare_recprice_data(df_recprice)
df_recprice_prepared.to_parquet(DATA_ROOT_PATH / 'df_recprice_prepared.pqt')

# %% [markdown]
# __Bids__

# %%
df_bids = download_bid_data(
    start_date=BEFORE_START_DATE,
    stop_date=EXP_STOP_DATE,
    city_id=CITY_ID,
    user_name=USER_NAME,
    # printBool=True
)

# Применяем функцию group_name к каждой строке, используя user_id как split_id
df_bids['bid_group_name'] = df_bids.apply(
    lambda row: 'Before' if row['utc_order_dttm'] < pd.Timestamp(EXP_START_DATE, tz='UTC') 
    else group_name(row['user_id'], EXP_SALT, DISTRIBUTION_MAP),
    axis=1
)

df_bids.to_parquet(DATA_ROOT_PATH / 'df_bids.pqt')

# %%
df_bids = pd.read_parquet(DATA_ROOT_PATH / 'df_bids.pqt')
df_bids_prepared = prepare_bid_data(df_bids)
df_bids_prepared.to_parquet(DATA_ROOT_PATH / 'df_bids_prepared.pqt')

# %% [markdown]
# __Orders (with recprice)__

# %%
df_orders = download_order_data(
    start_date=BEFORE_START_DATE,
    stop_date=EXP_STOP_DATE,
    city_id=CITY_ID,
    user_name=USER_NAME,
    # printBool=False
)

# Применяем функцию group_name к каждой строке, используя user_id как split_id
df_orders['order_group_name'] = df_orders.apply(
    lambda row: 'Before' if row['utc_order_dttm'] < pd.Timestamp(EXP_START_DATE, tz='UTC') 
    else group_name(row['user_id'], EXP_SALT, DISTRIBUTION_MAP),
    axis=1
)

df_orders.to_parquet(DATA_ROOT_PATH / 'df_orders.pqt')

# %%
df_orders = pd.read_parquet(DATA_ROOT_PATH / 'df_orders.pqt')
df_orders_prepared = prepare_order_data(df_orders)
df_orders_prepared.to_parquet(DATA_ROOT_PATH / 'df_orders_prepared.pqt')

# %%
df_orders_with_recprice = get_orders_with_recprice_df(df_orders_prepared, df_recprice_prepared)
df_orders_with_recprice['group_name'] = df_orders_with_recprice['recprice_group_name']
df_orders_with_recprice.to_parquet(DATA_ROOT_PATH / 'df_orders_with_recprice.pqt')
# Out:
# только уникальные ордера? – True
# доля оставшихся ордеров: 0.9728

# %% [markdown]
# ### Results

# %%
# EXP_ID = 2574
# DATA_ROOT_PATH = pathlib.Path(f'data/exp_id={EXP_ID}')

# df_recprice_prepared = pd.read_parquet(DATA_ROOT_PATH / 'df_recprice_prepared.pqt')
# df_orders_with_recprice = pd.read_parquet(DATA_ROOT_PATH / 'df_orders_with_recprice.pqt')

# %%
pd.set_option('display.max_rows', None)
# pd.reset_option('display.max_rows')

# %%
df_recprice_prepared = pd.read_parquet(DATA_ROOT_PATH / 'df_recprice_prepared.pqt')
df_orders_with_recprice = pd.read_parquet(DATA_ROOT_PATH / 'df_orders_with_recprice.pqt')
df_bids_prepared = pd.read_parquet(DATA_ROOT_PATH / 'df_bids_prepared.pqt')

# %% [markdown]
# __Total__

# %%
df_metrics_total = calculate_absolute_metrics(
    df_recprice_prepared,
    df_orders_with_recprice,
    df_bids_prepared,
    group_cols=['group_name', 'order_uuid'],
)

metrics_total_tbl = get_switchback_results(df_metrics_total, alpha=0.05)[
    ['metric', 'control_value', 'experimental_value', 'uplift_rel', 'pvalue', 'is_significant']
]

metrics_total_tbl.head()
# Out:
#                     metric  control_value  experimental_value  uplift_rel  \
# 0        drivers_per_order       1.926175            1.926713    0.000279
# 1           bids_per_order       2.111355            2.110571   -0.000371
# 2          bids_per_driver       1.096139            1.095426   -0.000651
# 3  bids_per_order_with_bid       2.385093            2.380252   -0.002030
# 4      bids_per_done_order       2.327085            2.321976   -0.002195
#
#      pvalue  is_significant
# 0  0.836709           False
# 1  0.818043           False
# 2  0.292706           False
# 3  0.170620           False
# 4  0.160554           False

# %%
metrics_total_tbl
# Out:
#                                      metric  control_value  \
# 0                         drivers_per_order   1.926175e+00
# 1                            bids_per_order   2.111355e+00
# 2                           bids_per_driver   1.096139e+00
# 3                   bids_per_order_with_bid   2.385093e+00
# 4                       bids_per_done_order   2.327085e+00
# 5               drivers_per_orders_with_bid   2.175905e+00
# 6                  bids_accepted_per_driver   4.066644e-01
# 7                        price_highrate_usd   2.970135e+00
# 8                  price_highrate_usd_rides   2.841368e+00
# 9    price_highrate_usd_orders_without_bids   3.606307e+00
# 10                          price_start_usd   2.984495e+00
# 11                    price_start_usd_rides   2.868675e+00
# 12      price_start_usd_orders_without_bids   3.599731e+00
# 13                       price_bid_currency   6.541385e+01
# 14              price_bid_option_startprice   5.793764e+01
# 15                 price_bid_option_option1   6.400704e+01
# 16                 price_bid_option_option2   6.849334e+01
# 17                 price_bid_option_option3   7.530353e+01
# 18                  price_bid_option_other1   6.784211e+01
# 19                  price_bid_option_other2   6.623810e+01
# 20                  price_bid_option_other3   6.500000e+01
# 21                         price_tender_usd   1.460563e+00
# 22                           price_done_usd   3.050481e+00
# 23                                order2bid   8.852293e-01
# 24              order2bid_option_startprice   5.845033e-01
# 25                 order2bid_option_option1   1.843388e-01
# 26                 order2bid_option_option2   3.134287e-01
# 27                 order2bid_option_option3   3.373299e-01
# 28                  order2bid_option_other1   2.970458e-05
# 29                  order2bid_option_other2   3.283138e-05
# 30                  order2bid_option_other3   1.563399e-06
# 31                             order2accept   7.833207e-01
# 32           order2accept_option_startprice   9.013473e-01
# 33              order2accept_option_option1   4.467598e-01
# 34              order2accept_option_option2   3.086857e-01
# 35              order2accept_option_option3   2.291824e-01
# 36               order2accept_option_other1   6.842105e-01
# 37               order2accept_option_other2   9.047619e-01
# 38               order2accept_option_other3   0.000000e+00
# 39                               order2done   7.300416e-01
# 40         order2done_bid_option_startprice   4.930272e-01
# 41            order2done_bid_option_option1   7.682230e-02
# 42            order2done_bid_option_option2   8.966718e-02
# 43            order2done_bid_option_option3   7.045145e-02
# 44             order2done_bid_option_other1   1.719739e-05
# 45             order2done_bid_option_other2   2.814118e-05
# 46             order2done_bid_option_other3   0.000000e+00
# 47                               bid2accept   8.848789e-01
# 48             bid_option_startprice2accept   9.013473e-01
# 49                bid_option_option12accept   4.467598e-01
# 50                bid_option_option22accept   3.086857e-01
# 51                bid_option_option32accept   2.291824e-01
# 52                 bid_option_other12accept   6.842105e-01
# 53                 bid_option_other22accept   9.047619e-01
# 54                 bid_option_other32accept   0.000000e+00
# 55                              accept2done   9.319831e-01
# 56     accepted_bids_option_startprice2done   9.358189e-01
# 57        accepted_bids_option_option12done   9.328170e-01
# 58        accepted_bids_option_option22done   9.267836e-01
# 59        accepted_bids_option_option32done   9.112841e-01
# 60         accepted_bids_option_other12done   8.461538e-01
# 61         accepted_bids_option_other22done   9.473684e-01
# 62         accepted_bids_option_other32done            NaN
# 63                                 bid2done   8.246921e-01
# 64               bid_option_startprice2done   8.434978e-01
# 65                  bid_option_option12done   4.167451e-01
# 66                  bid_option_option22done   2.860848e-01
# 67                  bid_option_option32done   2.088503e-01
# 68                   bid_option_other12done   5.789474e-01
# 69                   bid_option_other22done   8.571429e-01
# 70                   bid_option_other32done   0.000000e+00
# 71             bids_option_startprice_share   4.134810e-01
# 72                bids_option_option1_share   1.103970e-01
# 73                bids_option_option2_share   2.146576e-01
# 74                bids_option_option3_share   2.614340e-01
# 75                 bids_option_other1_share   1.406897e-05
# 76                 bids_option_other2_share   1.554991e-05
# 77                 bids_option_other3_share   7.404720e-07
# 78                      accepted_bids_share   3.709972e-01
# 79     accepted_share_bid_option_startprice   6.034792e-01
# 80        accepted_share_bid_option_option1   3.533235e-01
# 81        accepted_share_bid_option_option2   2.134753e-01
# 82        accepted_share_bid_option_option3   1.400596e-01
# 83         accepted_share_bid_option_other1   6.842105e-01
# 84         accepted_share_bid_option_other2   9.047619e-01
# 85         accepted_share_bid_option_other3   0.000000e+00
# 86         done_share_bid_option_startprice   9.358189e-01
# 87            done_share_bid_option_option1   9.328170e-01
# 88            done_share_bid_option_option2   9.267836e-01
# 89            done_share_bid_option_option3   9.112841e-01
# 90             done_share_bid_option_other1   8.461538e-01
# 91             done_share_bid_option_other2   9.473684e-01
# 92             done_share_bid_option_other3            NaN
# 93                                      eta   2.521669e+02
# 94                                      rta   2.225008e+02
# 95                                      etr   1.044929e+03
# 96                                      rtr   9.115152e+02
# 97                          eta_done_orders   8.111610e+01
# 98                        eta_accepted_bids   8.813684e+01
# 99                     etr_orders_with_bids   9.126189e+02
# 100           etr_orders_with_accepted_bids   7.934342e+02
# 101                         etr_done_orders   7.361413e+02
# 102                 etr_orders_without_bids   1.323101e+02
# 103                         time_to_1st_bid   4.033401e+01
# 104                  time_1st_bid_to_accept   7.207123e+01
#
#      experimental_value  uplift_rel    pvalue  is_significant
# 0          1.926713e+00    0.000279  0.836709           False
# 1          2.110571e+00   -0.000371  0.818043           False
# 2          1.095426e+00   -0.000651  0.292706           False
# 3          2.380252e+00   -0.002030  0.170620           False
# 4          2.321976e+00   -0.002195  0.160554           False
# 5          2.172902e+00   -0.001380  0.248046           False
# 6          4.074920e-01    0.002035  0.143567           False
# 7          2.970550e+00    0.000139  0.830372           False
# 8          2.841246e+00   -0.000043  0.936752           False
# 9          3.615327e+00    0.002501  0.435466           False
# 10         2.978612e+00   -0.001971  0.071017           False
# 11         2.868059e+00   -0.000215  0.726660           False
# 12         3.563040e+00   -0.010192  0.118763           False
# 13         6.545576e+01    0.000641  0.482080           False
# 14         5.799457e+01    0.000983  0.402424           False
# 15         6.403983e+01    0.000512  0.750815           False
# 16         6.850820e+01    0.000217  0.866043           False
# 17         7.540982e+01    0.001412  0.307960           False
# 18         6.520833e+01   -0.038822  0.581284           False
# 19         5.676471e+01   -0.143020  0.209786           False
# 20         7.500000e+01    0.153846  0.315134           False
# 21         1.462000e+00    0.000983  0.492533           False
# 22         3.050750e+00    0.000088  0.894156           False
# 23         8.867003e-01    0.001662  0.009020            True
# 24         5.852520e-01    0.001281  0.391236           False
# 25         1.840597e-01   -0.001514  0.684557           False
# 26         3.124611e-01   -0.003087  0.239021           False
# 27         3.381038e-01    0.002294  0.355848           False
# 28         3.786068e-05    0.274574  0.428354           False
# 29         2.681798e-05   -0.183160  0.534488           False
# 30         1.577528e-06    0.009038  0.994924           False
# 31         7.851343e-01    0.002315  0.012859            True
# 32         9.010143e-01   -0.000369  0.629957           False
# 33         4.492869e-01    0.005657  0.218808           False
# 34         3.089160e-01    0.000746  0.875141           False
# 35         2.322967e-01    0.013589  0.015237            True
# 36         5.833333e-01   -0.147436  0.445988           False
# 37         5.882353e-01   -0.349845  0.050374           False
# 38         1.000000e+00         inf  0.315134           False
# 39         7.308263e-01    0.001075  0.318383           False
# 40         4.928609e-01   -0.000337  0.851081           False
# 41         7.699285e-02    0.002220  0.717963           False
# 42         8.950265e-02   -0.001835  0.745126           False
# 43         7.140998e-02    0.013606  0.035127            True
# 44         2.050787e-05    0.192499  0.666982           False
# 45         1.419776e-05   -0.495481  0.087505           False
# 46         1.577528e-06         inf  0.315134           False
# 47         8.854562e-01    0.000652  0.335770           False
# 48         9.010143e-01   -0.000369  0.629957           False
# 49         4.492869e-01    0.005657  0.218808           False
# 50         3.089160e-01    0.000746  0.875141           False
# 51         2.322967e-01    0.013589  0.015237            True
# 52         5.833333e-01   -0.147436  0.445988           False
# 53         5.882353e-01   -0.349845  0.050374           False
# 54         1.000000e+00         inf  0.315134           False
# 55         9.308297e-01   -0.001238  0.022478            True
# 56         9.346516e-01   -0.001247  0.051915           False
# 57         9.310391e-01   -0.001906  0.251565           False
# 58         9.272558e-01    0.000510  0.750420           False
# 59         9.092132e-01   -0.002272  0.250059           False
# 60         9.285714e-01    0.097403  0.481871           False
# 61         9.000000e-01   -0.050000  0.727861           False
# 62                  NaN         NaN       NaN           False
# 63         8.242089e-01   -0.000586  0.499593           False
# 64         8.421345e-01   -0.001616  0.105793           False
# 65         4.183037e-01    0.003740  0.444410           False
# 66         2.864442e-01    0.001256  0.802156           False
# 67         2.112073e-01    0.011286  0.057487           False
# 68         5.416667e-01   -0.064394  0.782738           False
# 69         5.294118e-01   -0.382353  0.056807           False
# 70         1.000000e+00         inf  0.315134           False
# 71         4.149206e-01    0.003482  0.083413           False
# 72         1.104009e-01    0.000035  0.992864           False
# 73         2.133460e-01   -0.006110  0.021484            True
# 74         2.613011e-01   -0.000508  0.848028           False
# 75         1.793860e-05    0.275047  0.427729           False
# 76         1.270651e-05   -0.182857  0.535316           False
# 77         7.474417e-07    0.009413  0.994715           False
# 78         3.719943e-01    0.002688  0.111813           False
# 79         6.021570e-01   -0.002191  0.203862           False
# 80         3.549034e-01    0.004471  0.388337           False
# 81         2.143640e-01    0.004163  0.429778           False
# 82         1.424138e-01    0.016808  0.006340            True
# 83         5.833333e-01   -0.147436  0.445988           False
# 84         5.882353e-01   -0.349845  0.050374           False
# 85         1.000000e+00         inf  0.315134           False
# 86         9.346516e-01   -0.001247  0.051915           False
# 87         9.310391e-01   -0.001906  0.251565           False
# 88         9.272558e-01    0.000510  0.750420           False
# 89         9.092132e-01   -0.002272  0.250059           False
# 90         9.285714e-01    0.097403  0.481871           False
# 91         9.000000e-01   -0.050000  0.727861           False
# 92                  NaN         NaN       NaN           False
# 93         2.526006e+02    0.001720  0.018658            True
# 94         2.222358e+02   -0.001191  0.678415           False
# 95         1.044409e+03   -0.000497  0.748388           False
# 96         9.077513e+02   -0.004129  0.197376           False
# 97         8.130845e+01    0.002371  0.235815           False
# 98         8.844721e+01    0.003521  0.066957           False
# 99         9.133520e+02    0.000803  0.545609           False
# 100        7.943100e+02    0.001104  0.325081           False
# 101        7.358670e+02   -0.000373  0.705970           False
# 102        1.310572e+02   -0.009470  0.199386           False
# 103        4.035586e+01    0.000542  0.861868           False
# 104        7.083090e+01   -0.017210  0.142917           False

# %% [markdown]
# __By segment__

# %%
condition_on_recprice = df_recprice_prepared.order_type_id == ORDER_TYPE_ID
condition_on_orders = df_orders_with_recprice.order_type == ORDER_TYPE
condition_on_bids = df_bids_prepared.order_type == ORDER_TYPE

df_metrics_total = calculate_absolute_metrics(
    df_recprice_prepared[condition_on_recprice].copy(),
    df_orders_with_recprice[condition_on_orders].copy(),
    df_bids_prepared[condition_on_bids].copy(),
    group_cols=['group_name', 'switch_start_dttm', 'switch_finish_dttm'],
)

metrics_total_tbl = get_switchback_results(df_metrics_total, alpha=0.05)[
    ['metric', 'control_value', 'experimental_value', 'uplift_rel', 'pvalue', 'is_significant']
]

metrics_total_tbl
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 5
#       2 condition_on_orders = df_orders_with_recprice.order_type == ORDER_TYPE
#       3 condition_on_bids = df_bids_prepared.order_type == ORDER_TYPE
# ----> 5 df_metrics_total = calculate_absolute_metrics(
#       6     df_recprice_prepared[condition_on_recprice].copy(),
#       7     df_orders_with_recprice[condition_on_orders].copy(),
#       8     df_bids_prepared[condition_on_bids].copy(),
#       9     group_cols=['group_name', 'switch_start_dttm', 'switch_finish_dttm'],
#      10 )
#      12 metrics_total_tbl = get_switchback_results(df_metrics_total, alpha=0.05)[
#      13     ['metric', 'control_value', 'experimental_value', 'uplift_rel', 'pvalue', 'is_significant']
#      14 ]
#      16 metrics_total_tbl
#
# File ~/PycharmProjects/work/badbids/exp_anal/SB/results/src/metrics_AB.py:855, in calculate_absolute_metrics(df_recprice, df_order_with_recprice, df_bid, group_cols)
#     853 def calculate_absolute_metrics(df_recprice, df_order_with_recprice, df_bid, group_cols):
#     854     dfm = (#metric_calcprices_count(df_recprice, group_cols)
# --> 855            metric_orders_count(df_order_with_recprice, group_cols)
#     856            .merge(metric_orders_without_bids_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     857            .merge(metric_drivers_count(df_bid, group_cols), on=group_cols, how='left')
#     858            .merge(metric_bids_count(df_bid, group_cols), on=group_cols, how='left')
#     859            .merge(metric_bids_for_done_orders_count(df_bid, group_cols), on=group_cols, how='left')
#     860            .merge(metric_bids_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     861            .merge(metric_accepted_bids_count(df_bid, group_cols), on=group_cols, how='left')
#     862            .merge(metric_accepted_bids_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     863            .merge(metric_tenders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     864            .merge(metric_orders_with_bids_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     865            .merge(metric_start_price_bid_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     866            .merge(metric_start_price_bid_accepted_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     867            .merge(metric_start_price_bid_rides_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     868            .merge(metric_accepted_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     869            .merge(metric_rides_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     870            .merge(TEST_rides_count_by_bids(df_bid, group_cols), on=group_cols, how='left')
#     871            .merge(metric_price_start_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     872            .merge(metric_rides_price_start_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     873            .merge(metric_orders_without_bids_price_start_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     874            .merge(metric_price_highrate_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     875            .merge(metric_rides_price_highrate_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     876            .merge(metric_orders_without_bids_price_highrate_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     877            .merge(metric_price_tender_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     878            .merge(metric_price_done_usd_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     879            #
#     880            .merge(metric_good_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     881         #    .merge(metric_price_base_usd_sum(df_recprice, group_cols), on=group_cols, how='left')
#     882         #    .merge(metric_recprice_usd_sum(df_recprice, group_cols), on=group_cols, how='left')
#     883         #    .merge(metric_minprice_usd_sum(df_recprice, group_cols), on=group_cols, how='left')
#     884         #    .merge(metric_surge_sum(df_recprice, group_cols), on=group_cols, how='left')
#     885         #    .merge(metric_surge_gr_1_sum(df_recprice, group_cols), on=group_cols, how='left')
#     886         #    .merge(metric_surge_gr_1_calcprices_count(df_recprice, group_cols), on=group_cols, how='left')
#     887         #    .merge(metric_surge_le_1_sum(df_recprice, group_cols), on=group_cols, how='left')
#     888         #    .merge(metric_surge_le_1_calcprices_count(df_recprice, group_cols), on=group_cols, how='left')
#     889            .merge(metric_orders_by_minprice_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     890            .merge(metric_orders_by_minprice_with_bids_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     891            .merge(metric_accepted_orders_by_minprice_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     892            .merge(metric_rides_by_minprice_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     893            .merge(metric_surge_gr_1_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     894            .merge(metric_surge_le_1_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     895            .merge(metric_surge_gr_1_orders_with_bids_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     896            .merge(metric_surge_le_1_orders_with_bids_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     897            .merge(metric_surge_gr_1_start_price_bid_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     898            .merge(metric_surge_le_1_start_price_bid_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     899            .merge(metric_surge_gr_1_accepted_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     900            .merge(metric_surge_le_1_accepted_orders_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     901            .merge(metric_surge_gr_1_rides_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     902            .merge(metric_surge_le_1_rides_count(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     903            #
#     904            .merge(metric_rides_by_bid_option_startprice_count(df_bid, group_cols), on=group_cols, how='left')
#     905            .merge(metric_bids_option_startprice_count(df_bid, group_cols), on=group_cols, how='left')
#     906            .merge(metric_bids_option_startprice_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     907            .merge(metric_accepted_bids_option_startprice_count(df_bid, group_cols), on=group_cols, how='left')
#     908            .merge(metric_bids_option_startprice_accepted_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     909            .merge(metric_rides_by_bid_option_option1_count(df_bid, group_cols), on=group_cols, how='left')
#     910            .merge(metric_bids_option_option1_count(df_bid, group_cols), on=group_cols, how='left')
#     911            .merge(metric_bids_option_option1_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     912            .merge(metric_accepted_bids_option_option1_count(df_bid, group_cols), on=group_cols, how='left')
#     913            .merge(metric_accepted_bids_option_option1_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     914            .merge(metric_rides_by_bid_option_option2_count(df_bid, group_cols), on=group_cols, how='left')
#     915            .merge(metric_bids_option_option2_count(df_bid, group_cols), on=group_cols, how='left')
#     916            .merge(metric_bids_option_option2_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     917            .merge(metric_accepted_bids_option_option2_count(df_bid, group_cols), on=group_cols, how='left')
#     918            .merge(metric_accepted_bids_option_option2_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     919            .merge(metric_rides_by_bid_option_option3_count(df_bid, group_cols), on=group_cols, how='left')
#     920            .merge(metric_bids_option_option3_count(df_bid, group_cols), on=group_cols, how='left')
#     921            .merge(metric_bids_option_option3_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     922            .merge(metric_accepted_bids_option_option3_count(df_bid, group_cols), on=group_cols, how='left')
#     923            .merge(metric_accepted_bids_option_option3_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     924            .merge(metric_rides_by_bid_option_other1_count(df_bid, group_cols), on=group_cols, how='left')
#     925            .merge(metric_bids_option_other1_count(df_bid, group_cols), on=group_cols, how='left')
#     926            .merge(metric_bids_option_other1_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     927            .merge(metric_accepted_bids_option_other1_count(df_bid, group_cols), on=group_cols, how='left')
#     928            .merge(metric_accepted_bids_option_other1_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     929            .merge(metric_rides_by_bid_option_other2_count(df_bid, group_cols), on=group_cols, how='left')
#     930            .merge(metric_bids_option_other2_count(df_bid, group_cols), on=group_cols, how='left')
#     931            .merge(metric_bids_option_other2_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     932            .merge(metric_accepted_bids_option_other2_count(df_bid, group_cols), on=group_cols, how='left')
#     933            .merge(metric_accepted_bids_option_other2_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     934            .merge(metric_rides_by_bid_option_other3_count(df_bid, group_cols), on=group_cols, how='left')
#     935            .merge(metric_bids_option_other3_count(df_bid, group_cols), on=group_cols, how='left')
#     936            .merge(metric_bids_option_other3_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     937            .merge(metric_accepted_bids_option_other3_count(df_bid, group_cols), on=group_cols, how='left')
#     938            .merge(metric_accepted_bids_option_other3_bid_price_currency_sum(df_bid, group_cols), on=group_cols, how='left')
#     939            #
#     940            .merge(metric_orders_with_bid_option_startprice_count(df_bid, group_cols), on=group_cols, how='left')
#     941            .merge(metric_orders_with_bid_option_option1_count(df_bid, group_cols), on=group_cols, how='left')
#     942            .merge(metric_orders_with_bid_option_option2_count(df_bid, group_cols), on=group_cols, how='left')
#     943            .merge(metric_orders_with_bid_option_option3_count(df_bid, group_cols), on=group_cols, how='left')
#     944            .merge(metric_orders_with_bid_option_other1_count(df_bid, group_cols), on=group_cols, how='left')
#     945            .merge(metric_orders_with_bid_option_other2_count(df_bid, group_cols), on=group_cols, how='left')
#     946            .merge(metric_orders_with_bid_option_other3_count(df_bid, group_cols), on=group_cols, how='left')
#     947            #
#     948            .merge(metric_time_to_1st_bid_sec(df_bid, group_cols), on=group_cols, how='left')
#     949            .merge(metric_time_1st_bid_to_accept_sec(df_bid, group_cols), on=group_cols, how='left')
#     950            .merge(metric_rta_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     951            .merge(metric_rtr_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     952            .merge(metric_eta_sum(df_bid, group_cols), on=group_cols, how='left')
#     953            .merge(metric_etr_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     954            .merge(metric_eta_done_orders_sum(df_bid, group_cols), on=group_cols, how='left')
#     955            .merge(metric_eta_accepted_bids_sum(df_bid, group_cols), on=group_cols, how='left')
#     956            .merge(metric_etr_orders_with_bids_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     957            .merge(metric_etr_orders_with_accepted_bids_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     958            .merge(metric_etr_done_orders_sum(df_order_with_recprice, group_cols), on=group_cols, how='left')
#     959            .merge(metric_etr_orders_without_bids_sum(df_order_with_recprice, group_cols), on=group_cols, how='left'))
#     960     return dfm
#
# File ~/PycharmProjects/work/badbids/exp_anal/SB/results/src/metrics_AB.py:215, in metric_orders_count(df, group_cols)
#     214 def metric_orders_count(df, group_cols):
# --> 215     return (df
#     216             .groupby(group_cols)
#     217             .agg(orders_count=('order_uuid', 'nunique'))
#     218             .reset_index())
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/pandas/core/frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~/miniconda3/envs/py38/lib/python3.8/site-packages/pandas/core/groupby/grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'switch_start_dttm'
