# %%
# %load_ext autoreload
# %autoreload 2

import pathlib
import warnings
warnings.filterwarnings("ignore")

import mmh3
from typing import Dict
from datetime import timedelta
import pandas as pd

from src.download import download_experiment_data, download_recprice_data, download_order_data
from src.metrics import calculate_absolute_metrics, get_switchback_results, calculate_ratio_metrics
from src.prepare import prepare_recprice_data, prepare_order_data, get_orders_with_recprice_df, get_hex
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# salt - рандомная строка длиной 8 хранится в experiment.salt
# distribution_map - словарь вида {"GroupA": 50, "Control": 50}, где сумма значений должна быть 100
#  Порядок важен! Control всегда последний
def group_name(split_id: str, salt: str, distribution_map: Dict[str, int]):
    if sum(distribution_map.values()) != 100:
        raise Exception("Incorrect distribution")

    if list(distribution_map.keys())[-1] != "Control":
        raise Exception("Last group should be Control")

    if len(salt) != 8:
        raise Exception("Incorrect salt")

    # Хэш по соль экспа + split_id (id пользователя или девайса)
    murmur_hash: int = mmh3.hash(f"{salt}{split_id}", 1, False)
    reminder = murmur_hash % 100
    s = 0
    for k, v in distribution_map.items():
        s += v
        if reminder < s:
            return k

# %%
USER_NAME = 'nusuev_ab2608'
EXP_ID = 2608
ORDER_TYPE = 'auto_econom'
ORDER_TYPE_ID = 1
DAYS_BEFORE = 0

# %%
DATA_ROOT_PATH = pathlib.Path(f'data/exp_id={EXP_ID}')
if not DATA_ROOT_PATH.exists():
    DATA_ROOT_PATH.mkdir(parents=True, exist_ok=True)
    

PLOT_ROOT_PATH = pathlib.Path(f'data/exp_id={EXP_ID}/plots')
if not PLOT_ROOT_PATH.exists():
    PLOT_ROOT_PATH.mkdir(parents=True, exist_ok=True)

# %%
df_exp = download_experiment_data(EXP_ID, USER_NAME)
df_exp['city_id'] = 4269
df_exp
# Out:
#    exp_id  city_id  multiple_cities               status  \
# 0    2608     4269             True  completed
#
#              utc_start_dttm           utc_finish_dttm  exp_salt  \
# 0 2025-02-21 17:00:00+00:00 2025-03-14 17:00:00+00:00  XGm1V6Hj
#
#                                           conditions  utc_start_dttm_unix
# 0  {"and": [{"or": [{"version_greater_or_equal": ...           1740157200

# %%
EXP_START_DATE = df_exp.utc_start_dttm.dt.date.astype('str').iloc[0]
EXP_STOP_DATE = df_exp.utc_finish_dttm.dt.date.astype('str').iloc[0]
BEFORE_START_DATE = (df_exp.utc_start_dttm.dt.date - timedelta(days=DAYS_BEFORE)).astype('str').iloc[0]
CITY_ID = df_exp.city_id.iloc[0]
# EXP_NAME = df_exp.exp_na me.iloc[0]

exp_salt = df_exp['exp_salt'].iloc[0]
distribution_map = {"GroupA": 50, "Control": 50}

# Скачиваем данные по рекомендациям
df_recprice = download_recprice_data(
    start_date=BEFORE_START_DATE,
    stop_date=EXP_STOP_DATE,
    city_id=CITY_ID,
    user_name=USER_NAME,
)

# Применяем функцию group_name к каждой строке, используя user_id как split_id
df_recprice['recprice_group_name'] = df_recprice.apply(
    lambda row: 'Before' if row['utc_recprice_dttm'] < pd.Timestamp(EXP_START_DATE, tz='UTC') else group_name(row['user_id'], exp_salt, distribution_map),
    axis=1
)

df_recprice.to_parquet(DATA_ROOT_PATH / 'df_recprice.pqt')
df_recprice_prepared = prepare_recprice_data(df_recprice)
df_recprice_prepared.to_parquet(DATA_ROOT_PATH / 'df_recprice_prepared.pqt')

# Скачиваем данные по заказам
df_orders = download_order_data(
    start_date=BEFORE_START_DATE,
    stop_date=EXP_STOP_DATE,
    city_id=CITY_ID,
    user_name=USER_NAME,
)

# Применяем функцию group_name к каждой строке, используя user_id как split_id
df_orders['order_group_name'] = df_orders.apply(
    lambda row: 'Before' if row['utc_order_dttm'] < pd.Timestamp(EXP_START_DATE, tz='UTC') else group_name(row['user_id'], exp_salt, distribution_map),
    axis=1
)

df_orders.to_parquet(DATA_ROOT_PATH / 'df_orders.pqt')
df_orders_prepared = prepare_order_data(df_orders)
df_orders_prepared.to_parquet(DATA_ROOT_PATH / 'df_orders_prepared.pqt')

df_orders_with_recprice = get_orders_with_recprice_df(df_orders_prepared, df_recprice_prepared)
df_orders_with_recprice['group_name'] = df_orders_with_recprice['recprice_group_name']
df_orders_with_recprice.to_parquet(DATA_ROOT_PATH / 'df_orders_with_recprice.pqt')
# Out:
# только уникальные ордера? – True
# доля оставшихся ордеров: 0.9626

# %%
condition_on_recprice = df_recprice_prepared.order_type_id == ORDER_TYPE_ID
condition_on_orders = df_orders_with_recprice.order_type == ORDER_TYPE

df_metrics_total = calculate_absolute_metrics(
    df_recprice_prepared[condition_on_recprice].copy(),
    df_orders_with_recprice[condition_on_orders].copy(),
    group_cols=['user_id', 'group_name'],
    # group_cols=['order_uuid', 'group_name'],
)

metrics_total_tbl = get_switchback_results(df_metrics_total, alpha=0.05, groups={"control": "Control", "treatment": "GroupA"})[
    ['metric', 'control_value', 'experimental_value', 'uplift_rel', 'pvalue', 'is_significant']
]

metrics_total_tbl
# Out:
#                               metric  control_value  experimental_value  \
# 0                           cp2order       0.673654            0.669024
# 1                          order2bid       0.852694            0.854784
# 2              order2start_price_bid       0.523493            0.524519
# 3                       order2accept       0.698956            0.700015
# 4                         order2done       0.617964            0.620386
# 5                         bid2accept       0.819703            0.818938
# 6                  bids_per_accepted       1.129754            1.126747
# 7                      bid_price_avg       2.761878            2.765046
# 8                      bid_per_order       1.014751            1.015143
# 9                           bid2done       0.724720            0.725781
# 10            start_price_bid2accept       0.864234            0.865786
# 11              start_price_bid2done       0.768667            0.770901
# 12                            cp2bid       0.352653            0.350916
# 13                cp2start_price_bid       0.352653            0.350916
# 14                         cp2accept       0.470854            0.468326
# 15                           cp2done       0.416294            0.415053
# 16                      minprice_usd       3.569219            3.583457
# 17                    price_base_usd       4.560353            4.585886
# 18                      recprice_usd       4.835802            4.830651
# 19                price_highrate_usd       3.784999            3.775249
# 20          rides_price_highrate_usd       3.500892            3.504643
# 21                   price_start_usd       3.676137            3.671442
# 22             rides_price_start_usd       3.494727            3.501879
# 23                  price_tender_usd       1.806266            1.814983
# 24                    price_done_usd       3.772426            3.777951
# 25                             surge       1.038616            1.038365
# 26                        surge_gr_1       1.252866            1.252531
# 27                        surge_le_1       0.939203            0.939136
# 28               surge_gr_1_coverage       0.316942            0.316625
# 29               surge_le_1_coverage       0.683058            0.683375
# 30                         good_rate       0.590105            0.589054
# 31                           balance       0.954917            0.949495
# 32          orders_by_minprice_share       0.145906            0.144138
# 33    cp2order_by_orders_by_minprice       0.098290            0.096432
# 34  order2done_by_orders_by_minprice       0.606440            0.607147
# 35     cp2done_by_orders_by_minprice       0.059607            0.058548
# 36           surge_gr_1_orders_share       0.320030            0.318818
# 37           surge_le_1_orders_share       0.679970            0.681182
# 38            surge_gr_1_rides_share       0.271894            0.273380
# 39            surge_le_1_rides_share       0.728106            0.726620
# 40               surge_gr_1_cp2order       0.680218            0.673657
# 41               surge_le_1_cp2order       0.670608            0.666877
# 42             surge_gr_1_order2done       0.525015            0.531970
# 43             surge_le_1_order2done       0.661712            0.661768
# 44                surge_gr_1_cp2done       0.357124            0.358365
# 45                surge_le_1_cp2done       0.443749            0.441318
#
#     uplift_rel    pvalue  is_significant
# 0    -0.006873  0.193050           False
# 1     0.002451  0.385646           False
# 2     0.001960  0.746073           False
# 3     0.001514  0.747028           False
# 4     0.003919  0.465236           False
# 5    -0.000934  0.746334           False
# 6    -0.002661  0.198670           False
# 7     0.001147  0.833348           False
# 8     0.000386  0.914479           False
# 9     0.001465  0.693452           False
# 10    0.001796  0.469617           False
# 11    0.002906  0.402116           False
# 12   -0.004926  0.493421           False
# 13   -0.004926  0.493421           False
# 14   -0.005369  0.365029           False
# 15   -0.002980  0.643158           False
# 16    0.003989  0.777257           False
# 17    0.005599  0.700998           False
# 18   -0.001065  0.944197           False
# 19   -0.002576  0.512544           False
# 20    0.001072  0.734180           False
# 21   -0.001277  0.751261           False
# 22    0.002046  0.562964           False
# 23    0.004826  0.457884           False
# 24    0.001464  0.687628           False
# 25   -0.000242  0.871158           False
# 26   -0.000268  0.927197           False
# 27   -0.000071  0.883510           False
# 28   -0.001000  0.893165           False
# 29    0.000464  0.893165           False
# 30   -0.001782  0.814434           False
# 31   -0.005678  0.441791           False
# 32   -0.012115  0.587995           False
# 33   -0.018904  0.418787           False
# 34    0.001167  0.917526           False
# 35   -0.017759  0.486659           False
# 36   -0.003789  0.659900           False
# 37    0.001783  0.659900           False
# 38    0.005467  0.526500           False
# 39   -0.002042  0.526500           False
# 40   -0.009645  0.229358           False
# 41   -0.005563  0.318548           False
# 42    0.013247  0.137883           False
# 43    0.000086  0.987218           False
# 44    0.003474  0.713063           False
# 45   -0.005477  0.420353           False

# %%
df_metrics_total.groupby('group_name').sum().transpose()
# Out:
# group_name                                      Control          GroupA
# user_id                                   3666793198458   3619487651157
# calcprices_count                                 243931          245489
# orders_count                                   164325.0        164238.0
# tenders_count                                    325143          323997
# orders_with_bids_count                           140119          140388
# start_price_bid_orders_count                      86023           86146
# start_price_bid_accepted_orders_count             74344           74584
# start_price_bid_rides_count                       66123           66410
# accepted_orders_count                            114856          114969
# rides_count                                      101547          101891
# price_start_usd_sum                       604081.177831   602990.269345
# rides_price_start_usd_sum                 354879.088029   356809.947783
# price_highrate_usd_sum                    621970.037795   620039.323288
# rides_price_highrate_usd_sum              355505.058794   357091.606477
# price_tender_usd_sum                      587294.860076    588049.00976
# price_done_usd_sum                        383078.582906    384939.19129
# good_orders_count                               96969.0         96745.0
# price_base_usd_sum                       1112411.560644  1125784.565032
# recprice_usd_sum                         1179602.084152  1185871.593002
# minprice_usd_sum                          870643.038606   879699.280312
# surge_sum                                 253350.676805   254907.148709
# surge_gr_1_sum                             96861.610738    97356.731751
# surge_gr_1_calcprices_count                     77312.0         77728.0
# surge_le_1_sum                            156489.066067   157550.416958
# surge_le_1_calcprices_count                    166619.0        167761.0
# orders_by_minprice_count                        23976.0         23673.0
# orders_by_minprice_with_bids_count              20558.0         20251.0
# accepted_orders_by_minprice_count               16423.0         16217.0
# rides_by_minprice_count                         14540.0         14373.0
# surge_gr_1_orders_count                         52589.0         52362.0
# surge_le_1_orders_count                        111736.0        111876.0
# surge_gr_1_orders_with_bids_count               40199.0         40387.0
# surge_le_1_orders_with_bids_count               99920.0        100001.0
# surge_gr_1_start_price_bid_orders_count         23562.0         23839.0
# surge_le_1_start_price_bid_orders_count         62461.0         62307.0
# surge_gr_1_accepted_orders_count                31307.0         31599.0
# surge_le_1_accepted_orders_count                83549.0         83370.0
# surge_gr_1_rides_count                          27610.0         27855.0
# surge_le_1_rides_count                          73937.0         74036.0
# bids_on_accepted_orders_count                    129759          129541
# bids_prices_sum                           460540.459305   461002.236663
# bids_count                                       166749          166725

# %%
df_metrics_total.groupby('group_name')[['tenders_count', 'rides_count']].sum()
# Out:
#             tenders_count  rides_count
# group_name
# Before             492446       135033
# Control            524294       160687
# GroupA             528258       160785

# %%
df_recprice_prepared[condition_on_recprice]['utc_recprice_dttm'].min()
# df_orders_with_recprice[condition_on_orders]
# Out:
# Timestamp('2025-02-18 00:00:01+0000', tz='UTC')

# %%
old_df_recprice_prepared = df_recprice_prepared

# %%
df_recprice_prepared[condition_on_recprice]['utc_recprice_dttm'].min()
# Out:
# Timestamp('2025-02-28 00:00:02+0000', tz='UTC')
